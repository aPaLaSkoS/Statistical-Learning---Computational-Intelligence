# %% [markdown]
# # Imports

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import time, datetime, itertools, pickle
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.svm import SVC 
from sklearn.metrics import confusion_matrix
from sklearn.decomposition import PCA
from scipy.optimize import curve_fit
from itertools import permutations

# %% [markdown]
# # Read and Visualize results

# %% [markdown]
# ## 1. Linear kernel

# %%
results_df = pd.read_excel("/content/MNIST_linear.xlsx")
results_df.drop("Unnamed: 0", axis=1, inplace=True)

# %%
results_df
# Out:
#   dataset model  kernel            C       gamma  N_train  N_validation  \
# 0   MNIST   SVM  linear       0.0001  irrelevant    35999         24000
# 1   MNIST   SVM  linear       0.0010  irrelevant    35999         24000
# 2   MNIST   SVM  linear       0.0100  irrelevant    35999         24000
# 3   MNIST   SVM  linear       0.1000  irrelevant    35999         24000
# 4   MNIST   SVM  linear       1.0000  irrelevant    35999         24000
# 5   MNIST   SVM  linear      10.0000  irrelevant    35999         24000
# 6   MNIST   SVM  linear     100.0000  irrelevant    35999         24000
# 7   MNIST   SVM  linear    1000.0000  irrelevant    35999         24000
# 8   MNIST   SVM  linear   10000.0000  irrelevant    35999         24000
# 9   MNIST   SVM  linear  100000.0000  irrelevant    35999         24000
#
#    N_test   D PCA_applied k-fold Cross-Validation applied     Time elapsed  \
# 0    9999  87         YES                              NO  0h  7min  53sec
# 1    9999  87         YES                              NO  0h  7min  55sec
# 2    9999  87         YES                              NO   0h  4min  9sec
# 3    9999  87         YES                              NO  0h  1min  36sec
# 4    9999  87         YES                              NO  0h  0min  49sec
# 5    9999  87         YES                              NO  0h  0min  40sec
# 6    9999  87         YES                              NO   0h  1min  7sec
# 7    9999  87         YES                              NO  0h  4min  47sec
# 8    9999  87         YES                              NO  0h  36min  5sec
# 9    9999  87         YES                              NO   4h  7min  8sec
#
#    Train accuracy (%)  Validation accuracy (%)
# 0               11.13                    11.40
# 1               36.73                    37.07
# 2               89.47                    89.56
# 3               92.72                    92.58
# 4               94.16                    93.81
# 5               94.77                    93.97
# 6               95.05                    93.88
# 7               95.26                    93.73
# 8               95.29                    93.64
# 9               95.04                    93.55

# %%
results_df[results_df['Validation accuracy (%)'] == results_df['Validation accuracy (%)'].max()]
# Out:
#   dataset model  kernel     C       gamma  N_train  N_validation  N_test   D  \
# 5   MNIST   SVM  linear  10.0  irrelevant    35999         24000    9999  87
#
#   PCA_applied k-fold Cross-Validation applied     Time elapsed  \
# 5         YES                              NO  0h  0min  40sec
#
#    Train accuracy (%)  Validation accuracy (%)
# 5               94.77                    93.97

# %%
plt.figure(figsize=(30, 10))
plt.plot(results_df['C'].values, results_df['Train accuracy (%)'].values, label='Train')
plt.plot(results_df['C'].values, results_df['Validation accuracy (%)'].values, label='Validation')
plt.xlabel('C')
plt.ylabel('Accuracy (%)')
plt.title("MNIST Linear kernel")
plt.xscale('log')
plt.legend()
plt.show()

# %% [markdown]
# ## 2. RBF kernel

# %%
results_df = pd.read_excel(f"/content/MNIST_rbf.xlsx")
results_df.reset_index(inplace=True)
results_df.drop('index', axis=1, inplace=True)

# %%
results_df[50:]
# Out:
#     Unnamed: 0 dataset model kernel         C        gamma  N_train  \
# 50          50   MNIST   SVM    rbf      10.0       0.0001    35999
# 51          51   MNIST   SVM    rbf      10.0       0.0010    35999
# 52          52   MNIST   SVM    rbf      10.0       0.0100    35999
# 53          53   MNIST   SVM    rbf      10.0       0.1000    35999
# 54          54   MNIST   SVM    rbf      10.0       1.0000    35999
# 55          55   MNIST   SVM    rbf      10.0      10.0000    35999
# 56          56   MNIST   SVM    rbf      10.0     100.0000    35999
# 57          57   MNIST   SVM    rbf      10.0    1000.0000    35999
# 58          58   MNIST   SVM    rbf      10.0   10000.0000    35999
# 59          59   MNIST   SVM    rbf      10.0  100000.0000    35999
# 60          60   MNIST   SVM    rbf     100.0       0.0001    35999
# 61          61   MNIST   SVM    rbf     100.0       0.0010    35999
# 62          62   MNIST   SVM    rbf     100.0       0.0100    35999
# 63          63   MNIST   SVM    rbf     100.0       0.1000    35999
# 64          64   MNIST   SVM    rbf     100.0       1.0000    35999
# 65          65   MNIST   SVM    rbf     100.0      10.0000    35999
# 66          66   MNIST   SVM    rbf     100.0     100.0000    35999
# 67          67   MNIST   SVM    rbf     100.0    1000.0000    35999
# 68          68   MNIST   SVM    rbf     100.0   10000.0000    35999
# 69          69   MNIST   SVM    rbf     100.0  100000.0000    35999
# 70          70   MNIST   SVM    rbf    1000.0       0.0001    35999
# 71          71   MNIST   SVM    rbf    1000.0       0.0010    35999
# 72          72   MNIST   SVM    rbf    1000.0       0.0100    35999
# 73          73   MNIST   SVM    rbf    1000.0       0.1000    35999
# 74          74   MNIST   SVM    rbf    1000.0       1.0000    35999
# 75          75   MNIST   SVM    rbf    1000.0      10.0000    35999
# 76          76   MNIST   SVM    rbf    1000.0     100.0000    35999
# 77          77   MNIST   SVM    rbf    1000.0    1000.0000    35999
# 78          78   MNIST   SVM    rbf    1000.0   10000.0000    35999
# 79          79   MNIST   SVM    rbf    1000.0  100000.0000    35999
# 80          80   MNIST   SVM    rbf   10000.0       0.0001    35999
# 81          81   MNIST   SVM    rbf   10000.0       0.0010    35999
# 82          82   MNIST   SVM    rbf   10000.0       0.0100    35999
# 83          83   MNIST   SVM    rbf   10000.0       0.1000    35999
# 84          84   MNIST   SVM    rbf   10000.0       1.0000    35999
# 85          85   MNIST   SVM    rbf   10000.0      10.0000    35999
# 86          86   MNIST   SVM    rbf   10000.0     100.0000    35999
# 87          87   MNIST   SVM    rbf   10000.0    1000.0000    35999
# 88          88   MNIST   SVM    rbf   10000.0   10000.0000    35999
# 89          89   MNIST   SVM    rbf   10000.0  100000.0000    35999
# 90          90   MNIST   SVM    rbf  100000.0       0.0001    35999
# 91          91   MNIST   SVM    rbf  100000.0       0.0010    35999
# 92          92   MNIST   SVM    rbf  100000.0       0.0100    35999
# 93          93   MNIST   SVM    rbf  100000.0       0.1000    35999
# 94          94   MNIST   SVM    rbf  100000.0       1.0000    35999
# 95          95   MNIST   SVM    rbf  100000.0      10.0000    35999
# 96          96   MNIST   SVM    rbf  100000.0     100.0000    35999
# 97          97   MNIST   SVM    rbf  100000.0    1000.0000    35999
# 98          98   MNIST   SVM    rbf  100000.0   10000.0000    35999
# 99          99   MNIST   SVM    rbf  100000.0  100000.0000    35999
#
#     N_validation  N_test   D PCA_applied k-fold Cross-Validation applied  \
# 50         24000    9999  87         YES                              NO
# 51         24000    9999  87         YES                              NO
# 52         24000    9999  87         YES                              NO
# 53         24000    9999  87         YES                              NO
# 54         24000    9999  87         YES                              NO
# 55         24000    9999  87         YES                              NO
# 56         24000    9999  87         YES                              NO
# 57         24000    9999  87         YES                              NO
# 58         24000    9999  87         YES                              NO
# 59         24000    9999  87         YES                              NO
# 60         24000    9999  87         YES                              NO
# 61         24000    9999  87         YES                              NO
# 62         24000    9999  87         YES                              NO
# 63         24000    9999  87         YES                              NO
# 64         24000    9999  87         YES                              NO
# 65         24000    9999  87         YES                              NO
# 66         24000    9999  87         YES                              NO
# 67         24000    9999  87         YES                              NO
# 68         24000    9999  87         YES                              NO
# 69         24000    9999  87         YES                              NO
# 70         24000    9999  87         YES                              NO
# 71         24000    9999  87         YES                              NO
# 72         24000    9999  87         YES                              NO
# 73         24000    9999  87         YES                              NO
# 74         24000    9999  87         YES                              NO
# 75         24000    9999  87         YES                              NO
# 76         24000    9999  87         YES                              NO
# 77         24000    9999  87         YES                              NO
# 78         24000    9999  87         YES                              NO
# 79         24000    9999  87         YES                              NO
# 80         24000    9999  87         YES                              NO
# 81         24000    9999  87         YES                              NO
# 82         24000    9999  87         YES                              NO
# 83         24000    9999  87         YES                              NO
# 84         24000    9999  87         YES                              NO
# 85         24000    9999  87         YES                              NO
# 86         24000    9999  87         YES                              NO
# 87         24000    9999  87         YES                              NO
# 88         24000    9999  87         YES                              NO
# 89         24000    9999  87         YES                              NO
# 90         24000    9999  87         YES                              NO
# 91         24000    9999  87         YES                              NO
# 92         24000    9999  87         YES                              NO
# 93         24000    9999  87         YES                              NO
# 94         24000    9999  87         YES                              NO
# 95         24000    9999  87         YES                              NO
# 96         24000    9999  87         YES                              NO
# 97         24000    9999  87         YES                              NO
# 98         24000    9999  87         YES                              NO
# 99         24000    9999  87         YES                              NO
#
#         Time elapsed  Train accuracy (%)  Validation accuracy (%)
# 50   0h  11min  1sec               76.88                    76.64
# 51    0h  6min  7sec               90.76                    90.73
# 52   0h  2min  48sec               93.49                    93.15
# 53   0h  1min  34sec               97.71                    96.28
# 54   0h  2min  48sec              100.00                    98.08
# 55  0h  11min  11sec              100.00                    43.17
# 56   0h  13min  9sec              100.00                    11.27
# 57  0h  13min  17sec              100.00                    11.27
# 58  0h  12min  53sec              100.00                    11.27
# 59   0h  13min  4sec              100.00                    11.27
# 60   0h  5min  28sec               90.74                    90.73
# 61   0h  2min  46sec               93.36                    93.01
# 62   0h  1min  32sec               95.11                    94.19
# 63   0h  1min  28sec               99.87                    97.36
# 64   0h  2min  42sec              100.00                    98.08
# 65   0h  11min  5sec              100.00                    43.17
# 66  0h  12min  56sec              100.00                    11.27
# 67  0h  12min  58sec              100.00                    11.27
# 68  0h  12min  46sec              100.00                    11.27
# 69   0h  13min  0sec              100.00                    11.27
# 70   0h  2min  39sec               93.34                    92.99
# 71   0h  1min  36sec               94.61                    93.75
# 72   0h  1min  24sec               97.60                    95.66
# 73   0h  1min  25sec              100.00                    97.32
# 74   0h  2min  39sec              100.00                    98.08
# 75  0h  10min  59sec              100.00                    43.17
# 76  0h  12min  33sec              100.00                    11.27
# 77  0h  12min  55sec              100.00                    11.27
# 78  0h  12min  59sec              100.00                    11.27
# 79  0h  13min  21sec              100.00                    11.27
# 80   0h  1min  33sec               94.54                    93.71
# 81   0h  1min  22sec               95.40                    94.01
# 82   0h  1min  46sec               99.89                    96.93
# 83   0h  1min  24sec              100.00                    97.31
# 84   0h  2min  49sec              100.00                    98.08
# 85   0h  11min  9sec              100.00                    43.17
# 86  0h  13min  16sec              100.00                    11.27
# 87  0h  12min  59sec              100.00                    11.27
# 88  0h  12min  49sec              100.00                    11.27
# 89  0h  12min  43sec              100.00                    11.27
# 90   0h  1min  19sec               95.04                    93.68
# 91   0h  2min  14sec               97.57                    95.33
# 92   0h  1min  42sec              100.00                    96.92
# 93   0h  1min  26sec              100.00                    97.31
# 94   0h  2min  34sec              100.00                    98.08
# 95  0h  10min  52sec              100.00                    43.17
# 96  0h  12min  36sec              100.00                    11.27
# 97   0h  13min  9sec              100.00                    11.27
# 98  0h  12min  49sec              100.00                    11.27
# 99  0h  12min  58sec              100.00                    11.27

# %%
results_df[results_df['Validation accuracy (%)'] == results_df['Validation accuracy (%)'].max()]
# Out:
#     Unnamed: 0 dataset model kernel         C  gamma  N_train  N_validation  \
# 54          54   MNIST   SVM    rbf      10.0    1.0    35999         24000
# 64          64   MNIST   SVM    rbf     100.0    1.0    35999         24000
# 74          74   MNIST   SVM    rbf    1000.0    1.0    35999         24000
# 84          84   MNIST   SVM    rbf   10000.0    1.0    35999         24000
# 94          94   MNIST   SVM    rbf  100000.0    1.0    35999         24000
#
#     N_test   D PCA_applied k-fold Cross-Validation applied     Time elapsed  \
# 54    9999  87         YES                              NO  0h  2min  48sec
# 64    9999  87         YES                              NO  0h  2min  42sec
# 74    9999  87         YES                              NO  0h  2min  39sec
# 84    9999  87         YES                              NO  0h  2min  49sec
# 94    9999  87         YES                              NO  0h  2min  34sec
#
#     Train accuracy (%)  Validation accuracy (%)
# 54               100.0                    98.08
# 64               100.0                    98.08
# 74               100.0                    98.08
# 84               100.0                    98.08
# 94               100.0                    98.08

# %%
plt.figure(figsize=(30, 10))
for j, gamma in enumerate(np.unique(results_df['gamma'])):
  gamma_df = results_df[results_df['gamma'] == gamma]
  C_list = gamma_df['C'].values
  val_accuracy_list = gamma_df['Validation accuracy (%)'].values
  plt.plot(C_list, val_accuracy_list, label=f'gamma = {gamma}')

plt.xlabel('C')
plt.ylabel('Validation Accuracy (%)')
plt.title(f"MNIST RBF kernel")
plt.xscale('log')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(30, 10))
for j, gamma in enumerate(np.unique(results_df['gamma'])):
  gamma_df = results_df[results_df['gamma'] == gamma]
  C_list = gamma_df['C'].values
  train_accuracy_list = gamma_df['Train accuracy (%)'].values
  plt.plot(C_list, train_accuracy_list, label=f'gamma = {gamma}')

plt.xlabel('C')
plt.ylabel('Train Accuracy (%)')
plt.title(f"MNIST RBF kernel")
plt.xscale('log')
plt.legend()
plt.show()

# %%
fig, axs = plt.subplots(5, 2, figsize=(30, 30))
# fig.suptitle('CIFAR-10 RBF kernel')
for j, gamma in enumerate(np.unique(results_df['gamma'])):
  gamma_df = results_df[results_df['gamma'] == gamma]
  C_list = gamma_df['C'].values 
  train_accuracy_list = gamma_df['Train accuracy (%)'].values
  val_accuracy_list = gamma_df['Validation accuracy (%)'].values
  axs[j//2, j%2].plot(C_list, train_accuracy_list, label='train')
  axs[j//2, j%2].plot(C_list, val_accuracy_list, label='validation')
  axs[j//2, j%2].set_xscale('log')
  axs[j//2, j%2].set_xlabel("C")
  axs[j//2, j%2].set_ylabel("Accuracy (%)")
  axs[j//2, j%2].set_title(f"γ = {gamma}")
  axs[j//2, j%2].legend()

# %% [markdown]
# ## 3. Polynomial kernel

# %%
results_df = pd.read_excel("/content/MNIST_poly.xlsx")
results_df.drop("Unnamed: 0", axis=1, inplace=True)

# %%
results_df
# Out:
#    dataset model kernel  degree            C       gamma  N_train  \
# 0    MNIST   SVM   poly       2       0.0001  irrelevant    35999
# 1    MNIST   SVM   poly       2       0.0010  irrelevant    35999
# 2    MNIST   SVM   poly       2       0.0100  irrelevant    35999
# 3    MNIST   SVM   poly       2       0.1000  irrelevant    35999
# 4    MNIST   SVM   poly       2       1.0000  irrelevant    35999
# 5    MNIST   SVM   poly       2      10.0000  irrelevant    35999
# 6    MNIST   SVM   poly       2     100.0000  irrelevant    35999
# 7    MNIST   SVM   poly       2    1000.0000  irrelevant    35999
# 8    MNIST   SVM   poly       2   10000.0000  irrelevant    35999
# 9    MNIST   SVM   poly       2  100000.0000  irrelevant    35999
# 10   MNIST   SVM   poly       3       0.0001  irrelevant    35999
# 11   MNIST   SVM   poly       3       0.0010  irrelevant    35999
# 12   MNIST   SVM   poly       3       0.0100  irrelevant    35999
# 13   MNIST   SVM   poly       3       0.1000  irrelevant    35999
# 14   MNIST   SVM   poly       3       1.0000  irrelevant    35999
# 15   MNIST   SVM   poly       3      10.0000  irrelevant    35999
# 16   MNIST   SVM   poly       3     100.0000  irrelevant    35999
# 17   MNIST   SVM   poly       3    1000.0000  irrelevant    35999
# 18   MNIST   SVM   poly       3   10000.0000  irrelevant    35999
# 19   MNIST   SVM   poly       3  100000.0000  irrelevant    35999
# 20   MNIST   SVM   poly       4       0.0001  irrelevant    35999
# 21   MNIST   SVM   poly       4       0.0010  irrelevant    35999
# 22   MNIST   SVM   poly       4       0.0100  irrelevant    35999
# 23   MNIST   SVM   poly       4       0.1000  irrelevant    35999
# 24   MNIST   SVM   poly       4       1.0000  irrelevant    35999
# 25   MNIST   SVM   poly       4      10.0000  irrelevant    35999
# 26   MNIST   SVM   poly       4     100.0000  irrelevant    35999
# 27   MNIST   SVM   poly       4    1000.0000  irrelevant    35999
# 28   MNIST   SVM   poly       4   10000.0000  irrelevant    35999
# 29   MNIST   SVM   poly       4  100000.0000  irrelevant    35999
#
#     N_validation  N_test   D PCA_applied k-fold Cross-Validation applied  \
# 0          24000    9999  87         YES                              NO
# 1          24000    9999  87         YES                              NO
# 2          24000    9999  87         YES                              NO
# 3          24000    9999  87         YES                              NO
# 4          24000    9999  87         YES                              NO
# 5          24000    9999  87         YES                              NO
# 6          24000    9999  87         YES                              NO
# 7          24000    9999  87         YES                              NO
# 8          24000    9999  87         YES                              NO
# 9          24000    9999  87         YES                              NO
# 10         24000    9999  87         YES                              NO
# 11         24000    9999  87         YES                              NO
# 12         24000    9999  87         YES                              NO
# 13         24000    9999  87         YES                              NO
# 14         24000    9999  87         YES                              NO
# 15         24000    9999  87         YES                              NO
# 16         24000    9999  87         YES                              NO
# 17         24000    9999  87         YES                              NO
# 18         24000    9999  87         YES                              NO
# 19         24000    9999  87         YES                              NO
# 20         24000    9999  87         YES                              NO
# 21         24000    9999  87         YES                              NO
# 22         24000    9999  87         YES                              NO
# 23         24000    9999  87         YES                              NO
# 24         24000    9999  87         YES                              NO
# 25         24000    9999  87         YES                              NO
# 26         24000    9999  87         YES                              NO
# 27         24000    9999  87         YES                              NO
# 28         24000    9999  87         YES                              NO
# 29         24000    9999  87         YES                              NO
#
#        Time elapsed  Train accuracy (%)  Validation accuracy (%)
# 0    0h  4min  2sec               84.61                    84.40
# 1   0h  1min  42sec               91.63                    91.32
# 2   0h  0min  47sec               94.07                    93.57
# 3   0h  0min  29sec               96.21                    94.97
# 4   0h  0min  30sec               99.31                    96.82
# 5   0h  0min  33sec               99.99                    96.99
# 6   0h  0min  33sec              100.00                    96.98
# 7   0h  0min  33sec              100.00                    96.98
# 8   0h  0min  33sec              100.00                    96.98
# 9   0h  0min  33sec              100.00                    96.98
# 10  0h  1min  10sec               93.04                    92.58
# 11  0h  0min  36sec               95.39                    94.64
# 12  0h  0min  28sec               98.57                    96.56
# 13  0h  0min  30sec               99.97                    97.17
# 14  0h  0min  30sec              100.00                    97.10
# 15  0h  0min  30sec              100.00                    97.10
# 16  0h  0min  30sec              100.00                    97.10
# 17  0h  0min  30sec              100.00                    97.10
# 18  0h  0min  30sec              100.00                    97.10
# 19  0h  0min  27sec              100.00                    97.10
# 20  0h  0min  29sec               97.09                    95.74
# 21  0h  0min  28sec               99.76                    97.23
# 22  0h  0min  27sec              100.00                    97.20
# 23  0h  0min  27sec              100.00                    97.19
# 24  0h  0min  27sec              100.00                    97.19
# 25  0h  0min  27sec              100.00                    97.19
# 26  0h  0min  27sec              100.00                    97.19
# 27  0h  0min  27sec              100.00                    97.19
# 28  0h  0min  28sec              100.00                    97.19
# 29  0h  0min  27sec              100.00                    97.19

# %%
results_df[results_df['Validation accuracy (%)'] == results_df['Validation accuracy (%)'].max()]
# Out:
#    dataset model kernel  degree      C       gamma  N_train  N_validation  \
# 21   MNIST   SVM   poly       4  0.001  irrelevant    35999         24000
#
#     N_test   D PCA_applied k-fold Cross-Validation applied     Time elapsed  \
# 21    9999  87         YES                              NO  0h  0min  28sec
#
#     Train accuracy (%)  Validation accuracy (%)
# 21               99.76                    97.23

# %%
plt.figure(figsize=(30, 10))
for degree in np.unique(results_df['degree']):
  degree_df = results_df[results_df['degree'] == degree]
  C_list = degree_df['C'].values
  val_accuracy_list = degree_df['Train accuracy (%)'].values
  plt.plot(C_list, val_accuracy_list, label=f'degree = {degree}')

plt.xlabel('C')
plt.ylabel('Train Accuracy (%)')
plt.title("MNIST Polynomial kernel")
plt.xscale('log')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(30, 10))
for degree in np.unique(results_df['degree']):
  degree_df = results_df[results_df['degree'] == degree]
  C_list = degree_df['C'].values
  val_accuracy_list = degree_df['Validation accuracy (%)'].values
  plt.plot(C_list, val_accuracy_list, label=f'degree = {degree}')

plt.xlabel('C')
plt.ylabel('Validation Accuracy (%)')
plt.title("MNIST Polynomial kernel")
plt.xscale('log')
plt.legend()
plt.show()

# %%
for degree in np.unique(results_df['degree']):
  plt.figure(figsize=(30, 10))
  degree_df = results_df[results_df['degree'] == degree]
  C_list = degree_df['C'].values
  val_accuracy_list = degree_df['Validation accuracy (%)'].values
  train_accuracy_list = degree_df['Train accuracy (%)'].values
  plt.plot(C_list, train_accuracy_list, label='Train')
  plt.plot(C_list, val_accuracy_list, label='Validation')
  plt.xlabel('C')
  plt.ylabel('Accuracy (%)')
  plt.title(f"MNIST Polynomial kernel (d = {degree})")
  plt.xscale('log')
  plt.legend()
  plt.show()

# %% [markdown]
# ## 4. Sigmoid kernel

# %%
results_df = pd.read_excel("/content/MNIST_sigmoid.xlsx")
results_df.drop("Unnamed: 0", axis=1, inplace=True)

# %%
results_df
# Out:
#   dataset model   kernel            C       gamma  N_train  N_validation  \
# 0   MNIST   SVM  sigmoid       0.0001  irrelevant    35999         24000
# 1   MNIST   SVM  sigmoid       0.0010  irrelevant    35999         24000
# 2   MNIST   SVM  sigmoid       0.0100  irrelevant    35999         24000
# 3   MNIST   SVM  sigmoid       0.1000  irrelevant    35999         24000
# 4   MNIST   SVM  sigmoid       1.0000  irrelevant    35999         24000
# 5   MNIST   SVM  sigmoid      10.0000  irrelevant    35999         24000
# 6   MNIST   SVM  sigmoid     100.0000  irrelevant    35999         24000
# 7   MNIST   SVM  sigmoid    1000.0000  irrelevant    35999         24000
# 8   MNIST   SVM  sigmoid   10000.0000  irrelevant    35999         24000
# 9   MNIST   SVM  sigmoid  100000.0000  irrelevant    35999         24000
#
#    N_test   D PCA_applied k-fold Cross-Validation applied      Time elapsed  \
# 0    9999  87         YES                              NO  0h  12min  19sec
# 1    9999  87         YES                              NO  0h  11min  45sec
# 2    9999  87         YES                              NO  0h  10min  59sec
# 3    9999  87         YES                              NO  0h  10min  55sec
# 4    9999  87         YES                              NO  0h  10min  44sec
# 5    9999  87         YES                              NO  0h  10min  51sec
# 6    9999  87         YES                              NO  0h  10min  57sec
# 7    9999  87         YES                              NO  0h  10min  35sec
# 8    9999  87         YES                              NO  0h  10min  49sec
# 9    9999  87         YES                              NO  0h  10min  45sec
#
#    Train accuracy (%)  Validation accuracy (%)
# 0                  11                    11.59
# 1                  11                    11.59
# 2                  11                    11.59
# 3                  11                    11.59
# 4                  11                    11.59
# 5                  11                    11.59
# 6                  11                    11.59
# 7                  11                    11.59
# 8                  11                    11.59
# 9                  11                    11.59

# %%
plt.figure(figsize=(30, 10))
plt.plot(results_df['C'].values, results_df['Train accuracy (%)'].values, label='Train')
plt.plot(results_df['C'].values, results_df['Validation accuracy (%)'].values, label='Validation')
plt.xlabel('C')
plt.ylabel('Accuracy (%)')
plt.title("MNIST Sigmoid kernel")
plt.xscale('log')
plt.legend()
plt.show()

# %% [markdown]
# ## 5. KNN

# %%
results_df = pd.read_excel("/content/MNIST_KNN.xlsx")
results_df.drop("Unnamed: 0", axis=1, inplace=True)

# %%
results_df[50:]
# Out:
#    dataset model   K   weights  N_train  N_validation  N_test   D PCA_applied  \
# 50   MNIST   KNN   1  distance    35999         24000    9999  87         YES
# 51   MNIST   KNN   2  distance    35999         24000    9999  87         YES
# 52   MNIST   KNN   3  distance    35999         24000    9999  87         YES
# 53   MNIST   KNN   4  distance    35999         24000    9999  87         YES
# 54   MNIST   KNN   5  distance    35999         24000    9999  87         YES
# 55   MNIST   KNN   6  distance    35999         24000    9999  87         YES
# 56   MNIST   KNN   7  distance    35999         24000    9999  87         YES
# 57   MNIST   KNN   8  distance    35999         24000    9999  87         YES
# 58   MNIST   KNN   9  distance    35999         24000    9999  87         YES
# 59   MNIST   KNN  10  distance    35999         24000    9999  87         YES
# 60   MNIST   KNN  11  distance    35999         24000    9999  87         YES
# 61   MNIST   KNN  12  distance    35999         24000    9999  87         YES
# 62   MNIST   KNN  13  distance    35999         24000    9999  87         YES
# 63   MNIST   KNN  14  distance    35999         24000    9999  87         YES
# 64   MNIST   KNN  15  distance    35999         24000    9999  87         YES
# 65   MNIST   KNN  16  distance    35999         24000    9999  87         YES
# 66   MNIST   KNN  17  distance    35999         24000    9999  87         YES
# 67   MNIST   KNN  18  distance    35999         24000    9999  87         YES
# 68   MNIST   KNN  19  distance    35999         24000    9999  87         YES
# 69   MNIST   KNN  20  distance    35999         24000    9999  87         YES
# 70   MNIST   KNN  21  distance    35999         24000    9999  87         YES
# 71   MNIST   KNN  22  distance    35999         24000    9999  87         YES
# 72   MNIST   KNN  23  distance    35999         24000    9999  87         YES
# 73   MNIST   KNN  24  distance    35999         24000    9999  87         YES
# 74   MNIST   KNN  25  distance    35999         24000    9999  87         YES
# 75   MNIST   KNN  26  distance    35999         24000    9999  87         YES
# 76   MNIST   KNN  27  distance    35999         24000    9999  87         YES
# 77   MNIST   KNN  28  distance    35999         24000    9999  87         YES
# 78   MNIST   KNN  29  distance    35999         24000    9999  87         YES
# 79   MNIST   KNN  30  distance    35999         24000    9999  87         YES
# 80   MNIST   KNN  31  distance    35999         24000    9999  87         YES
# 81   MNIST   KNN  32  distance    35999         24000    9999  87         YES
# 82   MNIST   KNN  33  distance    35999         24000    9999  87         YES
# 83   MNIST   KNN  34  distance    35999         24000    9999  87         YES
# 84   MNIST   KNN  35  distance    35999         24000    9999  87         YES
# 85   MNIST   KNN  36  distance    35999         24000    9999  87         YES
# 86   MNIST   KNN  37  distance    35999         24000    9999  87         YES
# 87   MNIST   KNN  38  distance    35999         24000    9999  87         YES
# 88   MNIST   KNN  39  distance    35999         24000    9999  87         YES
# 89   MNIST   KNN  40  distance    35999         24000    9999  87         YES
# 90   MNIST   KNN  41  distance    35999         24000    9999  87         YES
# 91   MNIST   KNN  42  distance    35999         24000    9999  87         YES
# 92   MNIST   KNN  43  distance    35999         24000    9999  87         YES
# 93   MNIST   KNN  44  distance    35999         24000    9999  87         YES
# 94   MNIST   KNN  45  distance    35999         24000    9999  87         YES
# 95   MNIST   KNN  46  distance    35999         24000    9999  87         YES
# 96   MNIST   KNN  47  distance    35999         24000    9999  87         YES
# 97   MNIST   KNN  48  distance    35999         24000    9999  87         YES
# 98   MNIST   KNN  49  distance    35999         24000    9999  87         YES
# 99   MNIST   KNN  50  distance    35999         24000    9999  87         YES
#
#    k-fold Cross-Validation applied     Time elapsed  Train accuracy (%)  \
# 50                              NO  0h  0min  27sec               100.0
# 51                              NO  0h  0min  31sec               100.0
# 52                              NO  0h  0min  35sec               100.0
# 53                              NO  0h  0min  47sec               100.0
# 54                              NO  0h  0min  46sec               100.0
# 55                              NO  0h  0min  46sec               100.0
# 56                              NO  0h  0min  47sec               100.0
# 57                              NO  0h  0min  46sec               100.0
# 58                              NO  0h  0min  46sec               100.0
# 59                              NO  0h  0min  47sec               100.0
# 60                              NO  0h  0min  46sec               100.0
# 61                              NO  0h  0min  46sec               100.0
# 62                              NO  0h  0min  47sec               100.0
# 63                              NO  0h  0min  46sec               100.0
# 64                              NO  0h  0min  46sec               100.0
# 65                              NO  0h  0min  47sec               100.0
# 66                              NO  0h  0min  46sec               100.0
# 67                              NO  0h  0min  46sec               100.0
# 68                              NO  0h  0min  47sec               100.0
# 69                              NO  0h  0min  46sec               100.0
# 70                              NO  0h  0min  46sec               100.0
# 71                              NO  0h  0min  47sec               100.0
# 72                              NO  0h  0min  46sec               100.0
# 73                              NO  0h  0min  46sec               100.0
# 74                              NO  0h  0min  47sec               100.0
# 75                              NO  0h  0min  46sec               100.0
# 76                              NO  0h  0min  46sec               100.0
# 77                              NO  0h  0min  47sec               100.0
# 78                              NO  0h  0min  46sec               100.0
# 79                              NO  0h  0min  46sec               100.0
# 80                              NO  0h  0min  47sec               100.0
# 81                              NO  0h  0min  46sec               100.0
# 82                              NO  0h  0min  46sec               100.0
# 83                              NO  0h  0min  47sec               100.0
# 84                              NO  0h  0min  46sec               100.0
# 85                              NO  0h  0min  46sec               100.0
# 86                              NO  0h  0min  47sec               100.0
# 87                              NO  0h  0min  46sec               100.0
# 88                              NO  0h  0min  46sec               100.0
# 89                              NO  0h  0min  47sec               100.0
# 90                              NO  0h  0min  46sec               100.0
# 91                              NO  0h  0min  46sec               100.0
# 92                              NO  0h  0min  47sec               100.0
# 93                              NO  0h  0min  46sec               100.0
# 94                              NO  0h  0min  46sec               100.0
# 95                              NO  0h  0min  47sec               100.0
# 96                              NO  0h  0min  46sec               100.0
# 97                              NO  0h  0min  46sec               100.0
# 98                              NO  0h  0min  47sec               100.0
# 99                              NO  0h  0min  46sec               100.0
#
#     Validation accuracy (%)
# 50                    95.62
# 51                    95.62
# 52                    95.91
# 53                    96.07
# 54                    95.75
# 55                    95.84
# 56                    95.49
# 57                    95.58
# 58                    95.25
# 59                    95.26
# 60                    94.95
# 61                    94.90
# 62                    94.68
# 63                    94.67
# 64                    94.44
# 65                    94.40
# 66                    94.23
# 67                    94.15
# 68                    94.00
# 69                    93.98
# 70                    93.81
# 71                    93.75
# 72                    93.68
# 73                    93.61
# 74                    93.45
# 75                    93.40
# 76                    93.29
# 77                    93.25
# 78                    93.15
# 79                    93.10
# 80                    92.96
# 81                    92.93
# 82                    92.80
# 83                    92.71
# 84                    92.65
# 85                    92.63
# 86                    92.56
# 87                    92.50
# 88                    92.40
# 89                    92.28
# 90                    92.26
# 91                    92.21
# 92                    92.08
# 93                    92.06
# 94                    92.03
# 95                    91.94
# 96                    91.86
# 97                    91.83
# 98                    91.74
# 99                    91.73

# %%
df = results_df[(results_df['weights'] == 'uniform') & (results_df['K'] >= 10)]
df[df['Validation accuracy (%)'] == df['Validation accuracy (%)'].max()]
# Out:
#   dataset model   K  weights  N_train  N_validation  N_test   D PCA_applied  \
# 9   MNIST   KNN  10  uniform    35999         24000    9999  87         YES
#
#   k-fold Cross-Validation applied     Time elapsed  Train accuracy (%)  \
# 9                              NO  0h  0min  47sec               95.55
#
#    Validation accuracy (%)
# 9                    94.74

# %%
plt.figure(figsize=(30, 10))
for weight in np.unique(results_df['weights']):
  weight_df = results_df[results_df['weights'] == weight]
  K_list = weight_df['K'].values
  train_accuracy_list = weight_df['Train accuracy (%)'].values
  plt.plot(K_list, train_accuracy_list, label=f'weights = {weight}')

plt.xlabel('K')
plt.ylabel('Train Accuracy (%)')
plt.title("MNIST KNN")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(30, 10))
for weight in np.unique(results_df['weights']):
  weight_df = results_df[results_df['weights'] == weight]
  K_list = weight_df['K'].values
  val_accuracy_list = weight_df['Validation accuracy (%)'].values
  plt.plot(K_list, val_accuracy_list, label=f'weights = {weight}')

plt.xlabel('K')
plt.ylabel('Validation Accuracy (%)')
plt.title("MNIST KNN")
plt.legend()
plt.show()

# %%
for weight in np.unique(results_df['weights']):
  plt.figure(figsize=(30, 10))
  weight_df = results_df[results_df['weights'] == weight]
  K_list = weight_df['K'].values
  val_accuracy_list = weight_df['Validation accuracy (%)'].values
  train_accuracy_list = weight_df['Train accuracy (%)'].values
  plt.plot(K_list, train_accuracy_list, label='Train')
  plt.plot(K_list, val_accuracy_list, label='Validation')
  plt.xlabel('K')
  plt.ylabel('Accuracy (%)')
  plt.title(f"MNIST KNN (weights = {weight})")
  # plt.xscale('log')
  plt.legend()
  plt.show()
